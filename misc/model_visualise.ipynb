# %%
import keras
import pydot
import pydotplus
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model

keras.utils.vis_utils.pydot = pydot

# %%
model = keras.models.load_model(r"../models/neural_network/nn_v1")

# %%
plot_model(model, to_file='nn_model.png', show_shapes=True, show_layer_names=True, show_layer_activations=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 202)               41006
#
#  dropout (Dropout)           (None, 202)               0
#
#  dense_1 (Dense)             (None, 352)               71456
#
#  dropout_1 (Dropout)         (None, 352)               0
#
#  dense_2 (Dense)             (None, 160)               56480
#
#  dense_3 (Dense)             (None, 1)                 161
#
# ...
# Total params: 169,103
# Trainable params: 169,103
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jack_\OneDrive - University of Gloucestershire\Financial Technology (2022-2023)\final_project\misc\model_visualise.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jack_/OneDrive%20-%20University%20of%20Gloucestershire/Financial%20Technology%20%282022-2023%29/final_project/misc/model_visualise.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> model.layers()
#
# TypeError: 'list' object is not callable
